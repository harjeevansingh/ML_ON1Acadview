# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/harjeevansingh/ML_ON1Acadview/blob/master/assignment_6.ipynb)

# %%
##### Question 1 ####
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM  RainTomorrow
# 0      3.6           Yes
# 1      3.6           Yes
# 2     39.8           Yes
# 3      2.8           Yes
# 4      0.0            No
#
# [5 rows x 24 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.shape
# Out:
# (366, 24)

# %%
col=list(df.columns)
col
# Out:
# ['Date',
#  'Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RISK_MM',
#  'RainTomorrow']

# %%
itr =len(col)

# %%
#### countplot of Date
sns.countplot(x='Date', data=df)
sns.despine()
plt.title("1.Count plot of Date")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# Text(0.5,1,'1.Count plot of Date')

# %%
#### countplot of MinTemp
sns.countplot(x='MinTemp', data=df)
sns.despine()
plt.title("2.Count plot of MinTemp")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# Text(0.5,1,'2.Count plot of MinTemp')

# %%
#### distplot of MaxTemp
sns.distplot(df['MaxTemp'])
sns.despine()
plt.title("3.Dist plot of MaxTemp")
# Out:
# Text(0.5,1,'3.Dist plot of MaxTemp')

# %%
#### distplot of Rainfall
sns.distplot(df['Rainfall'])
sns.despine()
plt.title("4.Dist plot of Rainfall")
# Out:
# Text(0.5,1,'4.Dist plot of Rainfall')

# %%
sns.boxplot(x='Evaporation', y='Sunshine',data=df)
sns.despine()
plt.title("5.Box plot of 'Evaporation','Sunshine',")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# Text(0.5,1,"5.Box plot of 'Evaporation','Sunshine',")

# %%
sns.jointplot(x='Evaporation', y='Sunshine',data=df, alpha=0.2)
sns.despine()
plt.title("6. plot of 'WindGustDir','WindGustSpeed'")
# Out:
# Text(0.5,1,"6. plot of 'WindGustDir','WindGustSpeed'")

# %%
sns.boxplot(x= 'WindSpeed9am', y='WindSpeed3pm',data=df, hue='RainToday')
sns.despine()
plt.title("7.plot of  'WindSpeed9am','WindSpeed3pm'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
# Text(0.5,1,"7.plot of  'WindSpeed9am','WindSpeed3pm'")

# %%
sns.jointplot(x= 'Humidity9am', y='Humidity3pm',data=df)
sns.despine()
plt.title("8.plot of  'Humidity9am','Humidity3pm'")
# Out:
# Text(0.5,1,"8.plot of  'Humidity9am','Humidity3pm'")

# %%
sns.violinplot(x= 'Pressure9am', y='RainTomorrow',data=df)
sns.despine()
plt.title("plot of  'Pressure9am','RainTomorrow'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# Text(0.5,1,"plot of  'Pressure9am','RainTomorrow'")

# %%
df['RISK_MM'].plot(kind='barh')
sns.despine()
plt.title("10.plot of RISK_MM")
# Out:
# Text(0.5,1,'10.plot of RISK_MM')

# %%
sns.violinplot(x= 'Temp9am', y='Temp3pm',data=df,hue='RainToday' ,split= True, inner='stick',palette='Set2')
sns.despine()
plt.title("11. plot of  'Temp9am','Temp3pm'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:885: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:905: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# Text(0.5,1,"11. plot of  'Temp9am','Temp3pm'")

# %%
sns.violinplot(x= 'RainToday', y='WindSpeed9am',data=df, hue='RainTomorrow',split=True,inner='stick')
sns.despine()
plt.title("12. plot of  'RainToday','WindSpeed9am'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:885: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:905: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# Text(0.5,1,"12. plot of  'RainToday','WindSpeed9am'")

# %%
sns.violinplot(x= 'WindDir9am', y='WindSpeed9am',data=df, hue='RainTomorrow',inner='stick')
sns.despine()
plt.title("plot of  'WindDir9am','WindSpeed9am'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# Text(0.5,1,"plot of  'WindDir9am','WindSpeed9am'")

# %%
sns.boxplot(x= 'WindDir9am', y='Temp3pm',data=df,palette='Set2')
sns.despine()
plt.title("plot of  'WindDir9am','Temp3pm'")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# Text(0.5,1,"plot of  'WindDir9am','Temp3pm'")

# %%
sns.jointplot(x= 'Pressure3pm', y='Humidity3pm',data=df)
sns.despine()
plt.title("plot of  'Pressure3pm','Humidity3pm'")
# Out:
# Text(0.5,1,"plot of  'Pressure3pm','Humidity3pm'")

# %%
df['Rainfall'].plot(kind='pie')
sns.despine()

# %%
df['Sunshine'].plot(kind='barh')
sns.despine()

# %%
df['Evaporation'].plot(kind='pie')
sns.despine()

# %%
df['Humidity9am'].plot(kind='line')
sns.despine()

# %%
df['WindSpeed3pm'].plot(kind='bar')
sns.despine()
