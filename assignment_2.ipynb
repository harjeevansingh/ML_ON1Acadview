# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/harjeevansingh/ML_ON1Acadview/blob/master/assignment_2.ipynb)

# %%
##### Question 1 #####

import numpy as np

#creating an np array
a = np.random.rand(10,1)

#output the mean
print(np.mean(a))
# Out:
# 0.5322764294426962

# %%
##### Question 2 #####

b = np.random.rand(20,1)
print("Variance = ",np.var(b))  
print("Standard deviation = ",np.std(b))
# Out:
# Variance =  0.07569909942037722
# Standard deviation =  0.27513469323292766

# %%
##### Question 3 #####

a = np.random.rand(10,20)
b = np.random.rand(20,25)
c = np.dot(a,b)
print(c)

print(np.sum(c))
# Out:
# [[4.46848767 5.73571534 5.19329955 3.72425295 4.24072008 3.6967165
#   4.01503627 4.66831997 4.53335374 3.57890103 3.80981527 3.73426455
#   5.32996443 4.31531443 4.16797472 4.83117999 4.14440199 3.71519837
#   3.32974243 4.30278281 3.57549912 4.32796608 4.2560808  4.30265432
#   4.61093526]
#  [4.62174145 6.70746051 5.2021855  4.57202483 4.85289268 4.3597936
#   4.00082888 5.71355484 5.04785868 5.22027429 4.28622162 4.57973399
#   5.93886267 4.20649125 5.48280462 5.33749614 4.17567484 4.0143214
#   3.73980484 3.42147835 4.21426803 4.87298044 5.22858802 4.67809519
#   5.9409688 ]
#  [3.81605518 5.33548993 4.05361285 3.45390007 4.19562987 3.78480423
#   3.83297344 5.1942236  3.66427455 4.18205096 3.43197205 3.5047586
#   4.19705571 3.72168462 4.18426281 4.85247649 3.45696092 2.95961965
#   3.34846018 3.26801193 2.66785655 3.95069312 4.2111066  3.98926556
#   5.25432624]
#  [5.26751572 5.81625966 4.95453175 4.36629486 4.66642414 4.31195329
# ...

# %%
##### Question 4 #####

import math
a=np.random.rand(10,1)

def remix(x):
  return(1 / (1 + math.exp(-x)))

new_a = [remix(x) for x in a]
print(new_a)
# Out:
# [0.6694679691871003, 0.6048940296499808, 0.5038120246443034, 0.6939219945077186, 0.5662204827721684, 0.5136430769930956, 0.6005710970464788, 0.5343782207808682, 0.5331410260722445, 0.7278458627882155]
