# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/harjeevansingh/ML_ON1Acadview/blob/master/assignment_4.ipynb)

# %%
##### Quetion1 #####

import pandas as pd

info = {'name':['Harjeevan','Jaswinder','Abhiraj'],'age':[21,20,19],'ph no.':['9847447479','9135977456','8523497556'],'mail id':['harj@gmail.com','jas@gmail.com','abhi@gmail.com']}


details=pd.DataFrame(info)
print(details)
# Out:
#    age         mail id       name      ph no.
# 0   21  harj@gmail.com  Harjeevan  9847447479
# 1   20   jas@gmail.com  Jaswinder  9135977456
# 2   19  abhi@gmail.com    Abhiraj  8523497556

# %%
#### Question 2 ####

weather = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
weather.head()                                         # first 5 rows
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.head(10)                                       # first 10 rows
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
weather.iloc[-5:]                                      # last 5 rows
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
weather.iloc[0:26,0:12].describe()                      # stats of particular dataset
# Out:
#          MinTemp    MaxTemp   Rainfall  Evaporation   Sunshine  WindGustSpeed  \
# count  26.000000  26.000000  26.000000    26.000000  26.000000      26.000000
# mean   11.450000  25.115385   3.646154     6.015385   8.557692      41.461538
# std     3.106928   5.903334   9.385999     2.019048   3.620295      12.567357
# min     6.100000  15.500000   0.000000     1.200000   0.000000      26.000000
# 25%     8.575000  19.425000   0.000000     4.400000   7.550000      31.500000
# 50%    12.050000  26.050000   0.000000     6.000000   9.000000      41.000000
# 75%    13.775000  30.675000   1.050000     7.200000  10.975000      45.500000
# max    16.400000  33.400000  39.800000     9.200000  13.100000      85.000000
#
#        WindSpeed9am
# count     26.000000
# mean       9.076923
# std        6.933531
# min        2.000000
# 25%        6.000000
# 50%        6.000000
# 75%       10.500000
# max       30.000000

# %%
weather.iloc[:,1].describe()                            # stats on 2nd column
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object
